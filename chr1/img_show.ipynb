# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

img1 = imread('../dataset/lena.png') # 画像の読み込み
plt.imshow(img1)

plt.show()

# %%
img2 = imread('../dataset/lena_gray.png') # 画像の読み込み
plt.imshow(img2)

plt.show()
